# %%
import copy

with open('input.txt', 'r') as file:
    inDoc = file.read()
    
Lis = inDoc.split('\n')
Lis = [list(x) for x in Lis]

# %%
# for idx1, i in enumerate(Lis):
#     for idx2, j in enumerate(i):
#         if j == '^':
#             print(f'i, j : {idx1}, {idx2}')


numOfdots = 0
for idx1, i in enumerate(Lis):
    for idx2, j in enumerate(i):
        if j == '.':
            numOfdots += 1

print(numOfdots)
# Out:
# 16076

# %%
# list1 = Lis.copy()
# v = 55
# h = 86
# state = 'UP'
# outOfField = False

# while not outOfField:
#     if state == 'UP':
#         if v-1 < 0:
#             list1[v][h] = 'X'
#             outOfField = True
#             continue
#         elif list1[v-1][h] == '#':
#             state = 'RIGHT'
#             continue
#         elif list1[v-1][h] in ['.', 'X', '^']:
#             list1[v][h] = 'X'
#             v -= 1
#             continue
#     elif state == 'RIGHT':
#         if h+1 >= len(list1[0]) :
#             list1[v][h] = 'X'
#             outOfField = True
#             continue
#         elif list1[v][h+1] == '#':
#             state = 'DOWN'
#             continue
#         elif list1[v][h+1] in ['.', 'X', '^']:
#             list1[v][h] = 'X'
#             h += 1
#             continue
#     elif state == 'DOWN':
#         if v+1 >= len(list1) :
#             list1[v][h] = 'X'
#             outOfField = True
#             continue
#         elif list1[v+1][h] == '#':
#             state = 'LEFT'
#             continue
#         elif list1[v+1][h] in ['.', 'X', '^']:
#             list1[v][h] = 'X'
#             v += 1
#             continue
#     elif state == 'LEFT':
#         if h-1 < 0:
#             list1[v][h] = 'X'
#             outOfField = True
#             continue
#         elif list1[v][h-1] == '#':
#             state = 'UP'
#             continue
#         elif list1[v][h-1] in ['.', 'X', '^']:
#             list1[v][h] = 'X'
#             h -= 1
#             continue
        

# count = 0
# for idx1, i in enumerate(list1):
#     for idx2, j in enumerate(i):
#         if j in ['X', '^']:
#             count += 1
            
# print(count)

# %%
# paths = 0

# list1 = Lis.copy()
# v = 55
# h = 86
# state = 'UP'
# outOfField = False

# def move(outOfField, v, h, list1, state):
#     global paths
#     while not outOfField:
#         if state == 'UP':
#             if v-1 < 0:
                
#                 outOfField = True
#                 continue
#             elif list1[v-1][h] in ['#', 'O']:
#                 state = 'RIGHT'
#                 list1[v-1][h] = '#!'
#                 continue
#             elif list1[v-1][h] == '#!':
#                 paths += 1
#                 break
#             elif list1[v-1][h] in ['.', '^']:
                
#                 list1_ = list1.copy()
#                 list1_[v-1][h] = 'O'
#                 move(outOfField, v, h, list1_, state)
                
#                 v -= 1
#                 continue
                
                
#         elif state == 'RIGHT':
#             if h+1 >= len(list1[0]) :
                
#                 outOfField = True
#                 print('in')
#                 continue
#             elif list1[v][h+1] in ['#', 'O']:
#                 state = 'DOWN'
#                 list1[v][h+1] = '#!'
#                 continue
#             elif list1[v][h+1] == '#!':
#                 paths += 1
#                 break
#             elif list1[v][h+1] in ['.', '^']:
                
#                 list1_ = list1.copy()
#                 list1_[v][h+1] = 'O'
#                 move(outOfField, v, h, list1_, state)
                
#                 h += 1
#                 continue
                
            
#         elif state == 'DOWN':
#             if v+1 >= len(list1) :
            
#                 outOfField = True
#                 print('in')
#                 continue
#             elif list1[v+1][h] in ['#', 'O']:
#                 state = 'LEFT'
#                 list1[v+1][h] = '#!'
#                 continue
#             elif list1[v+1][h] == '#!':
#                 paths += 1
#                 break
#             elif list1[v+1][h] in ['.', '^']:
                
#                 list1_ = list1.copy()
#                 list1_[v+1][h] = 'O'
#                 move(outOfField, v, h, list1_, state)
                
#                 v += 1
#                 continue
                
                
#         elif state == 'LEFT':
#             if h-1 < 0:
                
#                 outOfField = True
#                 print('in')
#                 continue
#             elif list1[v][h-1] in ['#', 'O']:
#                 state = 'UP'
#                 list1[v][h-1] = '#!'
#                 continue
#             elif list1[v][h-1] == '#!':
#                 paths += 1
#                 break
#             elif list1[v][h-1] in ['.', '^']:
                
#                 list1_ = list1.copy()
#                 list1_[v][h-1] = 'O'
#                 move(outOfField, v, h, list1_, state)
                
#                 h -= 1
#                 continue
                
    
#     return

# move(outOfField, v, h, list1, state)

# print(paths)

# %%
paths = 0
dotNum = 0

# def move2(outOfField, v, h, list1, state):
#     global paths
#     while not outOfField:
#         if state == 'UP':
#             if v-1 < 0:
#                 outOfField = True
#                 continue
#             elif list1[v-1][h] == '#':
#                 state = 'RIGHT'
#                 list1[v-1][h] = '#!'
#                 continue
#             elif list1[v-1][h] == '#!':
#                 paths += 1
#                 break
#             elif list1[v-1][h] in ['.', '^']:
#                 v -= 1
#                 continue
                
                
#         elif state == 'RIGHT':
#             if h+1 >= len(list1[0]) :
#                 outOfField = True
#                 continue
#             elif list1[v][h+1] == '#':
#                 state = 'DOWN'
#                 list1[v][h+1] = '#!'
#                 continue
#             elif list1[v][h+1] == '#!':
#                 paths += 1
#                 break
#             elif list1[v][h+1] in ['.', '^']:
#                 h += 1
#                 continue
                
            
#         elif state == 'DOWN':
#             if v+1 >= len(list1) :
#                 outOfField = True
#                 continue
#             elif list1[v+1][h] == '#':
#                 state = 'LEFT'
#                 list1[v+1][h] = '#!'
#                 continue
#             elif list1[v+1][h] == '#!':
#                 paths += 1
#                 break
#             elif list1[v+1][h] in ['.', '^']:
#                 v += 1
#                 continue
                
                
#         elif state == 'LEFT':
#             if h-1 < 0:
#                 outOfField = True
#                 continue
#             elif list1[v][h-1] == '#':
#                 state = 'UP'
#                 list1[v][h-1] = '#!'
#                 continue
#             elif list1[v][h-1] == '#!':
#                 paths += 1
#                 break
#             elif list1[v][h-1] in ['.', '^']:
#                 h -= 1
#                 continue
                
#     return
    
    
for idx1_, i2 in enumerate(Lis):
    for idx2_, j2 in enumerate(i2):
    
        if Lis[idx1_][idx2_] == '.':
            dotNum += 1
            print(f'{dotNum} / 16076')
            list1 = copy.deepcopy(Lis)
            list1[idx1_][idx2_] = '#'
            v = 55
            h = 86
            state = 'UP'
            outOfField = False
            
            while not outOfField:
                if state == 'UP':
                    if v-1 < 0:
                        outOfField = True
                        continue
                    elif '#' in list1[v-1][h] and 'RIGHT' not in list1[v-1][h]:
                        state = 'RIGHT'
                        list1[v-1][h] += 'RIGHT'
                        continue
                    elif 'RIGHT' in list1[v-1][h]:
                        paths += 1
                        break
                    elif list1[v-1][h] in ['.', '^']:
                        v -= 1
                        continue
                    
                elif state == 'RIGHT':
                    if h+1 >= len(list1[0]):
                        outOfField = True
                        continue
                    elif '#' in list1[v][h+1] and 'DOWN' not in list1[v][h+1]:
                        state = 'DOWN'
                        list1[v][h+1] += 'DOWN'
                        continue
                    elif 'DOWN' in list1[v][h+1]:
                        paths += 1
                        break
                    elif list1[v][h+1] in ['.', '^']:
                        h += 1
                        continue
                    
                elif state == 'DOWN':
                    if v+1 >= len(list1) :
                        outOfField = True
                        continue
                    elif '#' in list1[v+1][h] and 'LEFT' not in list1[v+1][h]:
                        state = 'LEFT'
                        list1[v+1][h] += 'LEFT'
                        continue
                    elif 'LEFT' in list1[v+1][h]:
                        paths += 1
                        break
                    elif list1[v+1][h] in ['.', '^']:
                        v += 1
                        continue
                    
                elif state == 'LEFT':
                    if h-1 < 0:
                        outOfField = True
                        continue
                    elif '#' in list1[v][h-1] and 'UP' not in list1[v][h-1]:
                        state = 'UP'
                        list1[v][h-1] += 'UP'
                        continue
                    elif 'UP' in list1[v][h-1]:
                        paths += 1
                        break
                    elif list1[v][h-1] in ['.', '^']:
                        h -= 1
                        continue
                        

print(paths)
# Out:
# 1 / 16076
# 2 / 16076
# 3 / 16076
# 4 / 16076
# 5 / 16076
# 6 / 16076
# 7 / 16076
# 8 / 16076
# 9 / 16076
# 10 / 16076
# 11 / 16076
# 12 / 16076
# 13 / 16076
# 14 / 16076
# 15 / 16076
# 16 / 16076
# 17 / 16076
# 18 / 16076
# 19 / 16076
# 20 / 16076
# 21 / 16076
# 22 / 16076
# 23 / 16076
# 24 / 16076
# 25 / 16076
# 26 / 16076
# 27 / 16076
# 28 / 16076
# 29 / 16076
# 30 / 16076
# 31 / 16076
# 32 / 16076
# 33 / 16076
# 34 / 16076
# 35 / 16076
# 36 / 16076
# 37 / 16076
# 38 / 16076
# 39 / 16076
# 40 / 16076
# 41 / 16076
# 42 / 16076
# 43 / 16076
# 44 / 16076
# 45 / 16076
# 46 / 16076
# 47 / 16076
# 48 / 16076
# 49 / 16076
# 50 / 16076
# 51 / 16076
# 52 / 16076
# 53 / 16076
# 54 / 16076
# 55 / 16076
# 56 / 16076
# 57 / 16076
# 58 / 16076
# 59 / 16076
# 60 / 16076
# 61 / 16076
# 62 / 16076
# 63 / 16076
# 64 / 16076
# 65 / 16076
# 66 / 16076
# 67 / 16076
# 68 / 16076
# 69 / 16076
# 70 / 16076
# 71 / 16076
# 72 / 16076
# 73 / 16076
# 74 / 16076
# 75 / 16076
# 76 / 16076
# 77 / 16076
# ...

# %%
# print('LEFT' not in '#DOWNUPRIGHTLEFT')
# Out:
# False
